# %% [markdown]
# <a href="https://colab.research.google.com/github/celii017/POO2/blob/main/Sistema_libreria_version_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from _typeshed import Self
from abc import ABC abstractmethod
class Persona (ABC):
  def __init__(self, nombre, correo, fecha_nacimiento):
    self.nombre = nombre
    self.correo = correo
    self.fecha_nacimiento = fecha_nacimiento

    @abstractmethod
    def mostrar_info(self):
      """Metodo abstracto: las subclases deben redifinirlo."""
      pass
   #----------------------------------------------------
   # Interfaz (abstracta): registrable
   # Representa un "Contrato" que define que una clase pueda registrar actividades
   #--------------------------------------------------------------
   class registrable(ABC);
         @abstractclassmethod
         def registrar_actividades(self, accion):
          pass


   #############################################################################
   ################# CLASES DERIVADAS DE PERSONA #######################
   # Clase de Estudiante (hereda de una persona)
   # Ejemplo de polimorfismo y clase abstracta: redefine mostrar_info()
   class Estudiante(Persona):
          def __init__(self, num_control, nombre, carrera, fecha_nacimiento, telefono, correo
              super().__init__(nombrre, correo, fecha_nacimiento)
              Self.num_control = num_control
              self.carrera = carrera
              self.telefono = telefono

  # Redefinicion del metodo abstracto de persona
  def mostrar_info(self):
    return (f"[Estudiante] Nombre: {self.nombre} |"
            f"Numero control: {self.num_control}"
# Out:
#   File "/tmp/ipython-input-1318673234.py", line 1
#     from abc import ABC abstractmethod
#                         ^
# SyntaxError: invalid syntax
